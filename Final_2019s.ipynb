# %% [markdown]
# # Final projects

# %% [markdown]
# __<div style="text-align: right"> EE370: Software lab, Kyung Hee University. </div>__
# _<div style="text-align: right"> Jong-Han Kim (jonghank@khu.ac.kr) </div>_

# %% [markdown]
# You can choose one of the following problems for your final project.
#
# These are open questions: you can use whatever we discussed in class, or can even use whatever modules or others' codes (if you believe those are reliable) you can find over the internet. However you have to clearly note the reference, and have to clearly show (by explaining in comments or in markdown cells) that you fully understood the code or modules. Also, you should fully explain in details what you intend to do or what you are doing. You have to justify your approach for yourself in order to show that it makes sense and show that it works. Results without sufficient explanations or reasonable justifications will get no credit.
#
# Completed works should be turned in to the instructor and the course assistant no later than June 19th.

# %% [markdown]
# ---
#
# ## Organizing Lego blocks
#
# There are more than 100 distinct colors in Lego blocks (https://www.flickr.com/photos/126975831@N07/15801189140), but you have only 12 containers in which all your lego blocks should be categorized by similar colors and kept.
#
# You will build a Lego organizing machine that 1) takes a Lego block and measures its RGB color (this part can be replaced by an image of Lego block), and 2) determines the container to which the incoming Lego block should be sent (this part is what you design). Make a code that receives an image of Lego block as an input and returns the container number to which the incoming block should belong to. Explain what kind of colors are covered by each of the containers.
#
# You can find the color chart of existing Lego blocks from http://www.peeron.com/cgi-bin/invcgis/colorguide.cgi, https://lego.fandom.com/wiki/Colour_Palette, or https://swooshable.com/parts/colors.

# %%
# your code here

# %% [markdown]
# ---
# ## Aircraft detection
#
# Download the following four video clips. Make a code that detects the aircrafts. Your code may mark a bounding box around the aircrafts, or just show the pixels at which the center (or nose or whatever) of the aircraft is.
#
# http://jonghank.github.io/ee370/files/cockpit_video1.mp4
#
# http://jonghank.github.io/ee370/files/cockpit_video2.mp4
#
# http://jonghank.github.io/ee370/files/cockpit_video3.mp4
#
# http://jonghank.github.io/ee370/files/cockpit_video4.mp4

# %%
# your code here

# %% [markdown]
# ---
# ## No surprises
#
# You will make a code that automatically finds the dominating musical notes from a song. Use the song at https://www.youtube.com/watch?v=u5CVsCnxyXg, and find the dominating musical notes appreaing in the first 26 seconds (the intro part).

# %%
# your code here

# %% [markdown]
# ---
# ## Detecting unusual bank transactions

# %% [markdown]
# Download a `csv` file (http://jonghank.github.io/ee370/files/bank.csv), which contains bank transaction data collected from several bank accounts. Build a model that can detect unusual transactions (or fraud attempts).

# %%
import pandas as pd
df = pd.read_csv('http://jonghank.github.io/ee370/files/bank.csv')

# your code here
